# %% [markdown]
# <a href="https://colab.research.google.com/github/mahesh2356899/FMML-LAB1/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 09:56:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   136MB/s    in 0.5s
#
# 2024-03-30 09:56:06 (136 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36424   1401.3472v1  In this paper, we investigate knowledge reason...    cs
# 10086  1704.00783v1  I make some basic observations about hard take...    cs
# 5278    1209.1450v1  Researchers in functional neuroimaging mostly ...  stat
# 5488    1109.0455v1  This paper proposes a novel kernel approach to...  stat
# 17034  1708.00563v1  In this paper, we offer an in-depth analysis a...    cs
# ...             ...                                                ...   ...
# 2134   1603.06288v2  In many scientific and engineering application...  stat
# 2537   1512.07650v1  We consider the Max $K$-Armed Bandit problem, ...  stat
# 27564  1703.10584v1  This paper develops and evaluates a new tensor...    cs
# 32963  1511.07938v4  Early diagnosis of treatable diseases is essen...    cs
# 2980   1507.04125v2  Boosting algorithms have been widely used to t...    cs
#
#                                                    title  year  \
# 36424   Variable Forgetting in Reasoning about Knowledge  2014
# 10086  Brief Notes on Hard Takeoff, Value Alignment, ...  2017
# 5278   On spatial selectivity and prediction across c...  2012
# 5488   Gradient-based kernel dimension reduction for ...  2011
# 17034   Analyzing Neural MT Search and Model Performance  2017
# ...                                                  ...   ...
# 2134   Multi-fidelity Gaussian Process Bandit Optimis...  2016
# 2537   The Max $K$-Armed Bandit: PAC Lower Bounds and...  2015
# 27564  Geometric Affordances from a Single Example vi...  2017
# 32963  Temporal Convolutional Neural Networks for Dia...  2015
# 2980   Untangling AdaBoost-based Cost-Sensitive Class...  2015
#
#                                                 keywords
# 36424  [investigate, knowledge, reasoning, framework,...
# 10086  [observations, alignment, extrapolated, superi...
# 5278   [researchers, functional, neuroimaging, activa...
# 5488   [dimension, reduction, supervised, dimension, ...
# 17034  [performance, algorithm, necessary, furthermor...
# ...                                                  ...
# 2134   [scientific, engineering, applications, optimi...
# 2537   [stochastic, distribution, considered, designa...
# 27564  [evaluates, representation, geometric, afforda...
# 32963  [diagnosis, treatable, essential, improving, h...
# 2980   [algorithms, approaches, sensitive, capabiliti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36424    [investigate, knowledge, reasoning, framework,...
# 10086    [observations, alignment, extrapolated, superi...
# 5278     [researchers, functional, neuroimaging, activa...
# 5488     [dimension, reduction, supervised, dimension, ...
# 17034    [performance, algorithm, necessary, furthermor...
#                                ...
# 21521    [quadratic, necessity, obtaining, sensitivity,...
# 6682     [collection, factorization, combinations, arch...
# 21718    [applications, simulation, important, unavaila...
# 4421     [introduction, community, information, convent...
# 7423     [techniques, tremendous, optimization, nestero...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8790 words.
# Out of those 4595 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d8df1807-8dfa-46fb-8d11-11c9bfc2f498" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8df1807-8dfa-46fb-8d11-11c9bfc2f498")) {                    Plotly.newPlot(                        "d8df1807-8dfa-46fb-8d11-11c9bfc2f498",                        [{"x":["computational","condition","complexity","scenarios","automated","information","investigate","background","generalized","sufficient","interesting","structure","important","reasoning","conveniently","corresponding","verification","knowledge","schroeder","operation","presentation","observable","available","applications","epistemic","forgetting","framework","variables","alignment","superintelligent","observations","extrapolated","conditions","approaches","different","selection","statistical","hypotheses","particular","neuroimaging","activation","formulate","quantification","prediction","researchers","preliminary","coordinates","discriminating","selectivity","similarities","functional","successfully","efficient","eigendecomposition","experimental","reproducing","supervised","regression","computation","applicability","distributions","computationally","effective","comparison","covariance","reduction","operators","dimension","directions","effectively","assumptions","estimator","independently","performance","necessary","translations","separating","algorithm","influence","comparing","furthermore","algorithms","relatively","promising","differently","analyzing","rescoring","applicable","translation","reranking","performing","benchmarked","wikipedia","representation","leveraged","surprisingly","allocation","distributed","modelling","representations","sentiment","similarity","operations","encouraging","significantly","improvement","unsupervised","embedding","dirichlet","embeddings","dimensionality","paragraph","refinement","clustering","educational","contingency","generates","instances","annotations","experimentally","annotating","annotation","interacting","profoundly","generative","deviation","distances","inevitable","consideration","perceptual","imperceptible","maximizes","adversarial","tolerance","perturbations","technique","vulnerable","mainstream","perception","malicious","demonstrate","ubiquitous","factorisation","structural","techniques","computations","manuscript","dimensional","permutation","closeness","properties","experiments","deterministic","application","tessellated","recommendation","addresses","recognition","detecting","construction","individual","attributes","aggregation","signature","interested","dimensions","aggregated","descriptive","character","retrieval","comparable","characters","descriptors","explicitly","leveraging","parameters","expectation","numerical","sequential","nonnegative","estimation","approximation","maximisation","likelihood","precisely","stochastic","substituting","probabilities","statistics","unfeasible","inclusion","computing","manageable","described","counterparts","illustrated","undoubtedly","affecting","asymptotic","resulting"],"y":[268,65,250,86,100,671,157,87,75,70,73,357,366,120,5,126,35,363,1,37,8,33,294,460,7,6,568,152,53,3,79,3,140,470,731,162,146,20,269,5,39,61,13,217,74,50,16,5,5,35,42,93,375,0,367,8,188,143,164,34,103,106,261,145,21,95,59,69,29,111,71,22,33,867,78,16,10,855,64,72,168,621,56,116,8,78,3,53,114,3,73,3,18,366,10,32,25,98,37,248,46,161,66,20,252,160,130,102,13,73,56,6,31,126,4,5,54,92,57,66,10,63,17,2,117,15,39,4,26,31,7,14,107,4,25,256,14,3,50,7,585,17,3,76,356,33,5,182,10,2,205,594,45,256,3,32,54,366,66,63,108,64,31,6,26,42,9,18,52,97,85,31,51,83,39,270,36,73,74,7,254,123,3,61,24,135,2,58,63,1,6,120,3,64,10,20,2,6,17,157],"type":"bar"},{"x":["computational","condition","complexity","scenarios","automated","informatio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4595,), (4595, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.775

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Complex</span> <span style=''>Gaussian</span> <span style=''>Kernel</span> <span style=''>LMS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>Although</span> <span style=''>the</span> <span style=''>real</span> <span style='background-color:rgba(255, 0, 0, 0.75);'>reproducing</span> <span style=''>kernels</span> <span style=''>are</span> <span style=''>used</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3475177304964539);'>increasing</span> <span style=''>number</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>complex</span> <span style=''>kernels</span> <span style=''>have</span> <span style=''>not</span> <span style=''>yet</span> <span style=''>been</span> <span style=''>used</span> <span style=''>in</span> <span style=''>spite</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>interest</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>communications</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3301435406698565);'>attention</span> <span style=''>on</span> <span style=''>the</span> <span style=''>complex</span> <span style=''>gaussian</span> <span style=''>kernel</span> <span style=''>and</span> <span style=''>its</span> <span style=''>possible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>in</span> <span style=''>the</span> <span style=''>complex</span> <span style=''>Kernel</span> <span style=''>LMS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradients</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>complex</span> <span style=''>kernel</span> <span style=''>LMS</span> <span style=''>(CKLMS)</span> <span style=''>we</span> <span style=''>employ</span> <span style=''>the</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>of</span> <span style=''>Wirtingers</span> <span style=''>Calculus</span> <span style=''>which</span> <span style=''>has</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>attracted</span> <span style=''>much</span> <span style='background-color:rgba(0, 255, 0, 0.3301435406698565);'>attention</span> <span style=''>in</span> <span style=''>the</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.4317548746518106);'>processing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>community</span> <span style=''>Writingers</span> <span style=''>calculus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplifies</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>and</span> <span style=''>offers</span> <span style=''>an</span> <span style=''>elegant</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>treating</span> <span style=''>complex</span> <span style=''>signals</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>Writingers</span> <span style=''>calculus</span> <span style=''>is</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Rate</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Intervals</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>with</span> <span style=''>Missing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Covariates</span> <br/><br/><span style=''>Although</span> <span style=''>a</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>settings</span> <span style=''>which</span> <span style=''>involve</span> <span style=''>fully</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>settings</span> <span style=''>with</span> <span style=''>missing</span> <span style=''>values</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corruptions</span> <span style=''>are</span> <span style=''>common</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problems</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intervals</span> <span style=''>in</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>when</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>of</span> <span style=''>the</span> <span style=''>design</span> <span style=''>matrix</span> <span style=''>are</span> <span style=''>missing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completely</span> <span style=''>at</span> <span style=''>random</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Dantzig</span> <span style=''>selector</span> <span style=''>9</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>and</span> <span style=''>we</span> <span style=''>use</span> <span style=''>a</span> <span style=''>de</span> <span style=''>biasing</span> <span style=''>argument</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intervals</span> <span style=''>Our</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3000000000000001);'>Introduction</span> <span style=''>to</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Class</span> <span style=''>Notes</span> <span style=''>67577</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3000000000000001);'>Introduction</span> <span style=''>to</span> <span style=''>Machine</span> <span style=''>learning</span> <span style=''>covering</span> <span style='background-color:rgba(255, 0, 0, 0.3652173913043478);'>Statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>(Bayes</span> <span style=''>EM</span> <span style=''>MLMaxEnt</span> <span style=''>duality)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algebraic</span> <span style=''>and</span> <span style=''>spectral</span> <span style=''>methods</span> <span style=''>(PCA</span> <span style=''>LDA</span> <span style=''>CCA</span> <span style=''>Clustering)</span> <span style=''>and</span> <span style=''>PAC</span> <span style=''>learning</span> <span style=''>(the</span> <span style=''>Formal</span> <span style=''>model</span> <span style=''>VC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimension</span> <span style=''>Double</span> <span style=''>Sampling</span> <span style=''>theorem)</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style=''>Data</span> <span style=''>Using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Weighted</span> <span style=''>Average</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(RNN)</span> <span style=''>are</span> <span style=''>a</span> <span style=''>type</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>model</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>handle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>data</span> <span style=''>The</span> <span style=''>model</span> <span style=''>reads</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>one</span> <span style=''>symbol</span> <span style=''>at</span> <span style=''>a</span> <span style=''>time</span> <span style=''>Each</span> <span style=''>symbol</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>from</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>symbols</span> <span style=''>With</span> <span style=''>existing</span> <span style=''>RNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>each</span> <span style=''>symbol</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>using</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>from</span> <span style=''>the</span> <span style=''>previous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>step</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitation</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>kind</span> <span style=''>of</span> <span style=''>RNN</span> <span style=''>model</span> <span style=''>that</span> <span style=''>computes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>weighted</span> <span style=''>average</span> <span style=''>(RWA)</span> <span style=''>over</span> <span style=''>every</span> <span style=''>past</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>step</span> <span style=''>Because</span> <span style=''>the</span> <span style=''>RWA</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>running</span> <span style=''>average</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>overhead</span> <span style=''>scales</span> <span style=''>like</span> <span style=''>that</span> <span style=''>of</span> <span style=''>any</span> <span style=''>other</span> <span style=''>RNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>The</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reformulates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>at ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13011020263064343)
# 	information (0.23853537148951298)
# 	experimental (0.13046569498755778)
# 	architecture (0.08176324209029506)
# 	segmentation (0.06683256309989336)
# 	knowledge (0.12904372555990046)
# 	detection (0.1173124777817277)
# 	different (0.2598649129043726)
# 	recognition (0.13011020263064343)
# 	convolutional (0.135087095627444)
#
# Some Statistics words are:
# 	numerical (0.11172622043281329)
# 	variables (0.14393558127830902)
# 	stochastic (0.14192249622546552)
# 	algorithm (0.3995973829894313)
# 	distribution (0.17765475591343735)
# 	theoretical (0.1545042778057373)
# 	statistical (0.1580271766482134)
# 	inference (0.19778560644187218)
# 	dimensional (0.18621036738802216)
# 	regression (0.17564167086059387)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d4a57e6b-5647-4019-89d3-8faefa95ee90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4a57e6b-5647-4019-89d3-8faefa95ee90")) {                    Plotly.newPlot(                        "d4a57e6b-5647-4019-89d3-8faefa95ee90",                        [{"x":["computational","condition","complexity","scenarios","automated","information","investigate","background","generalized","sufficient","interesting","structure","important","reasoning","conveniently","corresponding","verification","knowledge","schroeder","operation","presentation","observable","available","applications","epistemic","forgetting","framework","variables","alignment","superintelligent","observations","extrapolated","conditions","approaches","different","selection","statistical","hypotheses","particular","neuroimaging","activation","formulate","quantification","prediction","researchers","preliminary","coordinates","discriminating","selectivity","similarities","functional","successfully","efficient","eigendecomposition","experimental","reproducing","supervised","regression","computation","applicability","distributions","computationally","effective","comparison","covariance","reduction","operators","dimension","directions","effectively","assumptions","estimator","independently","performance","necessary","translations","separating","algorithm","influence","comparing","furthermore","algorithms","relatively","promising","differently","analyzing","rescoring","applicable","translation","reranking","performing","benchmarked","wikipedia","representation","leveraged","surprisingly","allocation","distributed","modelling","representations","sentiment","similarity","operations","encouraging","significantly","improvement","unsupervised","embedding","dirichlet","embeddings","dimensionality","paragraph","refinement","clustering","educational","contingency","generates","instances","annotations","experimentally","annotating","annotation","interacting","profoundly","generative","deviation","distances","inevitable","consideration","perceptual","imperceptible","maximizes","adversarial","tolerance","perturbations","technique","vulnerable","mainstream","perception","malicious","demonstrate","ubiquitous","factorisation","structural","techniques","computations","manuscript","dimensional","permutation","closeness","properties","experiments","deterministic","application","tessellated","recommendation","addresses","recognition","detecting","construction","individual","attributes","aggregation","signature","interested","dimensions","aggregated","descriptive","character","retrieval","comparable","characters","descriptors","explicitly","leveraging","parameters","expectation","numerical","sequential","nonnegative","estimation","approximation","maximisation","likelihood","precisely","stochastic","substituting","probabilities","statistics","unfeasible","inclusion","computing","manageable","described","counterparts","illustrated","undoubtedly","affecting","asymptotic","resulting","appropriate","situations","carefully","lookahead","bootstrap","assignments","observing","functions","commitments","experimentation","maximizing","simulator","movements","companies","commitment","developed","commodity","simulates","contextual","calibrated","integrated","treatment","graphical","probabilistic","recommender","differences","understanding","principled","naturally","relationship","integrate","desirable","inference","intelligence","subsequent","neighborhoods","superiority","motivated","polarities","principles","detection","vocabulary","objective","successes","community","traditional","reinforcing","implementation","realistic","highlight","evolutions","extensions","circumstances","intervention","accomplish", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	eigendecomposition
# 	encrypted
# 	varepsilon
# 	stagewise
# 	marginalisation
# 	parameterizes
# 	modulating
# 	smoothers
# 	tibshirani
# 	backfitting
# 	unattainable
# 	quantifiable
# 	majorization
# 	biomarker
# 	transplantation
# 	covariates
# 	repertoires
# 	integrative
# 	prognostic
# 	parametrizations
# Some words which never appear in Statistics papers:
# 	superintelligent
# 	extrapolated
# 	rescoring
# 	benchmarked
# 	paragraph
# 	annotating
# 	profoundly
# 	descriptive
# 	formalisms
# 	breakthroughs
# 	syntactical
# 	integrity
# 	stylistic
# 	deceptive
# 	authorship
# 	commonsense
# 	transliteration
# 	termination
# 	decidable
# 	decidability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0557677616501144e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7158333333333333
